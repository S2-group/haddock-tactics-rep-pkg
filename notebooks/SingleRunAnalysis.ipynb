# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import re, sys, glob, os
import run_analysis as ra

# %%
import matplotlib.dates as mdates
import matplotlib.pyplot as plt

# %%
# get individual run path
# the runs with info regarding the modules are labeled with 'parsed'
dirs = glob.glob('../runs/run.dpp-local-nc16*parsed')

# %%
path = dirs[0]

# %%
print(path)
# Out:
# ../runs/run.dpp-local-nc16_gl5-33.cfg.parsed

# %%
# set the path of the directory needed to generate the plots
# use first the main function before generating any plots
ra.set_globals(dirs[0])

# %%
ra.gen_avg_frequency_plot()

# %%
ra.gen_avg_cpu_plot()

# %%
ra.gen_avg_mem_usage()

# %%
ra.gen_avg_cpu_per_core()

# %%
ra.gen_overall_plot()
