# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import parse_slurm as ps
import data_analysis as da
import glob
import pandas as pd

# %%
metric = 'Elapsed'

# %% [markdown]
# # Docking Protein-Protein Execution Time Analysis

# %%
dpp = pd.read_csv('../data/data_dpp.csv')
dpp = ps.remove_outliers_cpus(dpp, threshold=1, column=metric)
dpp.loc[:, 'Elapsed'] = dpp['Elapsed'] / 3600 
dpp_time = dpp[['Elapsed', 'NCPUS']]

# %% [markdown]
# ## Descriptive Analysis

# %%
for x in [4, 8, 16, 32]:
    group = dpp_time[dpp_time['NCPUS'] == x]
    print(group.describe())
    cv = group.std() / group.mean()
    print('cv', '   ', round(cv[metric], 6))
# Out:
#          Elapsed  NCPUS
# count  17.000000   17.0
# mean    1.261601    4.0
# std     0.054266    0.0
# min     1.202222    4.0
# 25%     1.213611    4.0
# 50%     1.256389    4.0
# 75%     1.289167    4.0
# max     1.406667    4.0
# cv     0.043014
#          Elapsed  NCPUS
# count  21.000000   21.0
# mean    0.708796    8.0
# std     0.013516    0.0
# min     0.686667    8.0
# 25%     0.696389    8.0
# 50%     0.710833    8.0
# 75%     0.718333    8.0
# max     0.736944    8.0
# cv     0.01907
#          Elapsed  NCPUS
# count  12.000000   12.0
# mean    0.450625   16.0
# std     0.010558    0.0
# min     0.440556   16.0
# 25%     0.444583   16.0
# 50%     0.447361   16.0
# 75%     0.451597   16.0
# max     0.478333   16.0
# cv     0.02343
#          Elapsed  NCPUS
# count  16.000000   16.0
# mean    0.365972   32.0
# std     0.013564    0.0
# min     0.349444   32.0
# 25%     0.352778   32.0
# 50%     0.367083   32.0
# 75%     0.370208   32.0
# max     0.393611   32.0
# cv     0.037062

# %% [markdown]
# ## Boxplots

# %%
da.show_boxplot(
    dpp_time, "Execution Time of DPP Workflow at Varying Parallelism Degrees", metric=metric,
    x_label="Number of vCPUs", y_label="Execution Time (h)", store=True
)

# %% [markdown]
# ### Normality Test: Shapiro-Wilk and QQ-Plots

# %%
normality = ps.test_normality(dpp_time, column=metric)
print(normality)
# Out:
#    NCPUS      STAT    PVALUE
# 0      4  0.886092  0.039963
# 1      8  0.968608  0.702069
# 2     16  0.802149  0.009912
# 3     32  0.915891  0.144830

# %%
ps.generate_qq(dpp_time, column=metric)

# %% [markdown]
# ## Hypothesis Testing: Kruskal-Wallis

# %%
ps.test_hypothesis_kruskal(dpp_time, column=metric)
# Out:
# (72.87055807314063, 1.036137014810735e-15)

# %% [markdown]
# ## Effect Size: Cliff's Delta

# %%
ps.calc_cliffs_delta(dpp_time, column=metric)
# Out:
#   CPUS-GROUPS     Value Result
# 0      (4, 8)  1.000000  large
# 1     (8, 16)  1.000000  large
# 2    (16, 32)  0.915789  large

# %% [markdown]
# ## Effect Size: Percentage Improvement

# %%
ps.calc_groups_improvement(dpp_time, column=metric)
# Out:
#   CPU-GROUPS  Median Improvement  Median Delta  Mean Improvement   Mean Delta
# 0     (4, 8)           78.211636        2003.0         82.861773  2140.584762
# 1    (8, 16)           58.281829         943.0         52.276496   886.853333
# 2   (16, 32)           21.745673         289.0         24.197074   330.519298
# 3    (4, 32)          243.416102        3235.0        245.833586  3357.957393

# %% [markdown]
# # Docking Antibody-Antigen Execution Time Analysis

# %%
daa = pd.read_csv('../data/data_daa.csv')
daa = ps.remove_outliers_cpus(daa, threshold=1, column=metric)
daa.loc[:, 'Elapsed'] = daa['Elapsed'] / 3600 
daa_time = daa[['Elapsed', 'NCPUS']]

# %% [markdown]
# # Descriptive Analysis

# %%
for x in [4, 8, 16, 32]:
    group = daa_time[daa_time['NCPUS'] == x]
    print(group.describe())
    cv = group.std() / group.mean()
    print('cv', '   ', round(cv[metric], 6))
# Out:
#             Elapsed  NCPUS
# count     18.000000   18.0
# mean   63978.555556    4.0
# std     1923.290692    0.0
# min    61831.000000    4.0
# 25%    62677.250000    4.0
# 50%    63082.500000    4.0
# 75%    65053.250000    4.0
# max    69122.000000    4.0
#             Elapsed  NCPUS
# count     20.000000   20.0
# mean   36719.200000    8.0
# std     1366.843371    0.0
# min    35406.000000    8.0
# 25%    35629.750000    8.0
# 50%    36358.000000    8.0
# 75%    37088.500000    8.0
# max    39658.000000    8.0
#             Elapsed  NCPUS
# count     13.000000   13.0
# mean   21950.153846   16.0
# std      429.559434    0.0
# min    21431.000000   16.0
# 25%    21533.000000   16.0
# 50%    22065.000000   16.0
# 75%    22160.000000   16.0
# max    22599.000000   16.0
#             Elapsed  NCPUS
# count     14.000000   14.0
# mean   17238.428571   32.0
# std      428.693133    0.0
# min    16584.000000   32.0
# 25%    17011.250000   32.0
# 50%    17191.500000   32.0
# 75%    17589.250000   32.0
# max    17874.000000   32.0

# %% [markdown]
# ## Boxplots

# %%
da.show_boxplot(
    daa_time, "Execution Time of DAA Workflow at Varying Parallelism Degrees", metric=metric,
    x_label="Number of vCPUs", y_label="Execution Time (h)", store=True
)

# %% [markdown]
# ## Normality Test: Shapiro-Wilk and QQ-Plots

# %%
normality = ps.test_normality(daa_time, column=metric)
print(normality)
# Out:
#    NCPUS      STAT    PVALUE
# 0      4  0.870357  0.018035
# 1      8  0.837503  0.003315
# 2     16  0.882566  0.077257
# 3     32  0.945594  0.494615

# %%
ps.generate_qq(daa_time, column=metric)

# %% [markdown]
# ## Hypothesis Testing: Kruskal-Wallis

# %%
ps.test_hypothesis_kruskal(daa_time, column=metric)
# Out:
# (59.639160839160866, 7.019945431976862e-13)

# %% [markdown]
# ## Effect Size: Cliff's Delta

# %%
ps.calc_cliffs_delta(daa_time, column=metric)
# Out:
#   CPUS-GROUPS  Value Result
# 0      (4, 8)    1.0  large
# 1     (8, 16)    1.0  large
# 2    (16, 32)    1.0  large

# %% [markdown]
# ## Effect Size: Percentage Improvement

# %%
ps.calc_groups_improvement(daa_time, column=metric)
# Out:
#   CPU-GROUPS  Median Improvement  Median Delta  Mean Improvement    Mean Delta
# 0     (4, 8)           73.503768       26724.5         74.237335  27259.355556
# 1    (8, 16)           64.776796       14293.0         67.284477  14769.046154
# 2   (16, 32)           28.348312        4873.5         27.332684   4711.725275
# 3    (4, 32)          266.940058       45891.0        271.139140  46740.126984
